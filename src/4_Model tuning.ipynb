# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import seaborn as sns
from scipy import stats
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error, mean_absolute_percentage_error
import time

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

import warnings
from sklearn import metrics 

warnings.simplefilter('ignore')

# %%
ds = pd.read_csv("data_set.csv")
ds.columns
# Out:
# Index(['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
#        'households', 'median_income', 'median_house_value',
#        'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
X_columns = ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
       'households', 'median_income',
       'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
       'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']


y_column =  ['median_house_value']

X = ds[X_columns]
y = ds[y_column]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
def model_metrics(ml_model, X_train, y_train, X_test, y_test):
    return ([str(ml_model).split("(")[0], 
                       ml_model.score(X_train, y_train), 
                       ml_model.score(X_test, y_test),
                       np.sqrt(mean_squared_error(y_train, ml_model.predict(X_train))),
                       np.sqrt(mean_squared_error(y_test, ml_model.predict(X_test))),
                       mean_absolute_error(y_train, ml_model.predict(X_train)),
                       mean_absolute_error(y_test, ml_model.predict(X_test)),
                       mean_absolute_percentage_error(y_train, ml_model.predict(X_train)),
                       mean_absolute_percentage_error(y_test, ml_model.predict(X_test)),
                      ])

# %%
rf = RandomForestRegressor(random_state = 42)

# %%
start = time.process_time()
result = []
ml_model = rf.fit(X_train, y_train)
temp_result = (model_metrics(ml_model, X_train, y_train, X_test, y_test))
print(str(rf).split("(")[0],"✓ ", "{}".format(round(time.process_time()-start,3)),"sec")

result_df = pd.DataFrame([temp_result], columns = ["Algorithm", "Train_Score", "Test_Score", "Train_RMSE",
                                         "Test_RMSE", "Train_MAE", "Test_MAE", "Train_MAPE", "Test_MAPE"])
result_df
# Out:
# RandomForestRegressor ✓  13.672 sec
#                Algorithm  Train_Score  Test_Score    Train_RMSE     Test_RMSE  \
# 0  RandomForestRegressor     0.988368    0.914467  14032.121016  37882.163006
#
#      Train_MAE     Test_MAE  Train_MAPE  Test_MAPE
# 0  6942.234664  19073.24579    0.040161    0.11183

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
# %%time
 param_grid = {'n_estimators': np.arange(50,100,10),
'max_features': [0.5, 0.6, 0.8],
'min_samples_split': [5,10,15],
'min_samples_leaf': [1,3,4],
'bootstrap': [False]}



rf = RandomForestRegressor()

grid = GridSearchCV(estimator=rf, 
                    param_grid=param_grid, 
                    scoring='neg_mean_absolute_percentage_error',
                    cv=5,
                    verbose = 3,
                    return_train_score=True)

grid.fit(X_train, y_train)

print("The best parameters are %s with a score of %0.2f"
      % (grid.best_params_, grid.best_score_))
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.016, test=-0.108) total time=   4.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.016, test=-0.100) total time=   4.9s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.016, test=-0.104) total time=   4.0s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.016, test=-0.099) total time=   3.8s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.016, test=-0.103) total time=   4.6s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.016, test=-0.108) total time=   6.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.016, test=-0.100) total time=   6.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.016, test=-0.103) total time=   7.0s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.016, test=-0.099) total time=   5.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.016, test=-0.104) total time=   4.7s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.015, test=-0.107) total time=   7.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.016, test=-0.100) total time=   7.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.016, test=-0.103) total time=   5.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.016, test=-0.099) total time=   5.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.016, test=-0.103) total time=   5.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.016, test=-0.108) total time=   7.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.016, test=-0.099) total time=   6.7s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.016, test=-0.103) total time=   6.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.016, test=-0.099) total time=   6.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.016, test=-0.103) total time=   7.3s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.107) total time=   7.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.016, test=-0.099) total time=   6.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.102) total time=   7.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.016, test=-0.099) total time=   7.5s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.103) total time=   6.6s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.045, test=-0.122) total time=   3.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.045, test=-0.115) total time=   3.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.045, test=-0.118) total time=   3.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.046, test=-0.115) total time=   3.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.045, test=-0.120) total time=   3.6s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.045, test=-0.122) total time=   4.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.045, test=-0.115) total time=   4.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.045, test=-0.117) total time=   4.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.046, test=-0.115) total time=   4.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.045, test=-0.119) total time=   4.3s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.044, test=-0.123) total time=   5.9s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.045, test=-0.116) total time=   7.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.045, test=-0.117) total time=   6.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.045, test=-0.115) total time=   5.0s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.045, test=-0.118) total time=   5.0s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.044, test=-0.122) total time=   5.8s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.045, test=-0.115) total time=   5.9s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.045, test=-0.117) total time=   6.0s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.045, test=-0.115) total time=   5.9s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.045, test=-0.119) total time=   5.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.044, test=-0.122) total time=   7.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.045, test=-0.115) total time=   6.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.045, test=-0.118) total time=   6.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.045, test=-0.115) total time=   5.9s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.045, test=-0.118) total time=   6.0s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.067, test=-0.134) total time=   3.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.068, test=-0.129) total time=   3.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.068, test=-0.129) total time=   3.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.069, test=-0.129) total time=   3.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.068, test=-0.132) total time=   3.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.067, test=-0.135) total time=   4.0s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.068, test=-0.128) total time=   3.8s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.068, test=-0.128) total time=   3.9s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.068, test=-0.128) total time=   4.1s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.068, test=-0.132) total time=   4.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.067, test=-0.135) total time=   4.8s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.068, test=-0.128) total time=   4.8s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.068, test=-0.129) total time=   4.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.068, test=-0.128) total time=   4.8s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.068, test=-0.132) total time=   4.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.067, test=-0.134) total time=   5.6s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.068, test=-0.127) total time=   5.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.067, test=-0.129) total time=   5.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.068, test=-0.128) total time=   5.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.067, test=-0.132) total time=   5.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.067, test=-0.135) total time=   6.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.068, test=-0.127) total time=   6.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.067, test=-0.129) total time=   5.8s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.068, test=-0.127) total time=   5.8s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.067, test=-0.132) total time=   5.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=50;, score=(train=-0.044, test=-0.122) total time=   3.7s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=50;, score=(train=-0.045, test=-0.116) total time=   3.6s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=50;, score=(train=-0.044, test=-0.118) total time=   3.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=50;, score=(train=-0.045, test=-0.115) total time=   3.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=50;, score=(train=-0.044, test=-0.117) total time=   3.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=60;, score=(train=-0.044, test=-0.121) total time=   4.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=60;, score=(train=-0.045, test=-0.115) total time=   4.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=60;, score=(train=-0.044, test=-0.117) total time=   4.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=60;, score=(train=-0.045, test=-0.115) total time=   4.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=60;, score=(train=-0.044, test=-0.117) total time=   4.3s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=70;, score=(train=-0.044, test=-0.122) total time=   5.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=70;, score=(train=-0.045, test=-0.115) total time=   5.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=70;, score=(train=-0.044, test=-0.117) total time=   5.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=70;, score=(train=-0.045, test=-0.114) total time=   5.1s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=70;, score=(train=-0.044, test=-0.118) total time=   4.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=80;, score=(train=-0.044, test=-0.121) total time=   5.7s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=80;, score=(train=-0.044, test=-0.115) total time=   5.9s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=80;, score=(train=-0.044, test=-0.117) total time=   5.9s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=80;, score=(train=-0.045, test=-0.114) total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=80;, score=(train=-0.044, test=-0.117) total time=   5.7s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=90;, score=(train=-0.043, test=-0.121) total time=   5.9s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=90;, score=(train=-0.044, test=-0.115) total time=   5.9s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=90;, score=(train=-0.044, test=-0.117) total time=   6.4s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=90;, score=(train=-0.044, test=-0.113) total time=   6.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=5, n_estimators=90;, score=(train=-0.044, test=-0.117) total time=   6.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=50;, score=(train=-0.059, test=-0.129) total time=   3.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=50;, score=(train=-0.060, test=-0.124) total time=   3.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=50;, score=(train=-0.059, test=-0.125) total time=   3.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=50;, score=(train=-0.060, test=-0.123) total time=   3.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=50;, score=(train=-0.060, test=-0.126) total time=   3.1s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=60;, score=(train=-0.058, test=-0.129) total time=   4.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=60;, score=(train=-0.059, test=-0.123) total time=   4.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=60;, score=(train=-0.058, test=-0.125) total time=   3.9s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=60;, score=(train=-0.060, test=-0.122) total time=   3.7s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=60;, score=(train=-0.059, test=-0.126) total time=   3.7s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=70;, score=(train=-0.058, test=-0.128) total time=   4.6s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=70;, score=(train=-0.059, test=-0.123) total time=   4.8s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=70;, score=(train=-0.059, test=-0.125) total time=   4.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=70;, score=(train=-0.059, test=-0.122) total time=   4.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=70;, score=(train=-0.059, test=-0.125) total time=   4.3s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=80;, score=(train=-0.058, test=-0.129) total time=   4.9s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=80;, score=(train=-0.059, test=-0.123) total time=   5.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=80;, score=(train=-0.058, test=-0.124) total time=   5.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=80;, score=(train=-0.059, test=-0.123) total time=   5.7s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=80;, score=(train=-0.059, test=-0.125) total time=   5.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=90;, score=(train=-0.058, test=-0.129) total time=   6.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=90;, score=(train=-0.059, test=-0.122) total time=   6.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=90;, score=(train=-0.058, test=-0.124) total time=   6.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=90;, score=(train=-0.059, test=-0.122) total time=   6.6s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=90;, score=(train=-0.059, test=-0.125) total time=   5.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.077, test=-0.139) total time=   3.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.078, test=-0.134) total time=   3.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.077, test=-0.134) total time=   3.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.078, test=-0.134) total time=   3.1s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.077, test=-0.136) total time=   3.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.077, test=-0.139) total time=   3.7s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.078, test=-0.133) total time=   3.8s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.077, test=-0.134) total time=   3.7s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.078, test=-0.133) total time=   3.8s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.077, test=-0.136) total time=   3.6s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.077, test=-0.139) total time=   4.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.078, test=-0.133) total time=   4.4s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.077, test=-0.134) total time=   4.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.078, test=-0.133) total time=   4.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.077, test=-0.136) total time=   4.4s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.077, test=-0.138) total time=   5.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.078, test=-0.133) total time=   5.2s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.077, test=-0.133) total time=   5.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.078, test=-0.133) total time=   5.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.077, test=-0.136) total time=   4.9s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.077, test=-0.139) total time=   6.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.078, test=-0.133) total time=   5.9s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.077, test=-0.134) total time=   6.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.078, test=-0.133) total time=   6.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.077, test=-0.135) total time=   5.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.061, test=-0.131) total time=   3.6s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.062, test=-0.125) total time=   6.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.061, test=-0.127) total time=   7.7s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.062, test=-0.124) total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.061, test=-0.127) total time=   4.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.061, test=-0.130) total time=   5.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.062, test=-0.124) total time=   7.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.061, test=-0.126) total time=   7.3s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.062, test=-0.123) total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.061, test=-0.126) total time=   4.1s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.061, test=-0.130) total time=   4.6s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.062, test=-0.124) total time=   4.6s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.061, test=-0.125) total time=   4.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.062, test=-0.123) total time=   4.6s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.061, test=-0.126) total time=   5.0s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.061, test=-0.129) total time=   5.2s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.062, test=-0.125) total time=   5.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.061, test=-0.125) total time=   5.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.062, test=-0.123) total time=   5.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.061, test=-0.126) total time=   5.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.060, test=-0.130) total time=   5.6s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.061, test=-0.124) total time=   5.8s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.061, test=-0.126) total time=   5.7s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.062, test=-0.123) total time=   5.7s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.061, test=-0.126) total time=   5.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.067, test=-0.133) total time=   3.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.067, test=-0.127) total time=   3.1s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.067, test=-0.129) total time=   3.0s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.068, test=-0.126) total time=   3.0s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.067, test=-0.129) total time=   3.0s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.066, test=-0.132) total time=   3.9s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.067, test=-0.127) total time=   3.6s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.066, test=-0.129) total time=   3.6s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.067, test=-0.127) total time=   4.2s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.067, test=-0.130) total time=   3.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.066, test=-0.133) total time=   4.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.067, test=-0.128) total time=   4.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.066, test=-0.128) total time=   4.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.067, test=-0.126) total time=   4.3s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.067, test=-0.130) total time=   4.2s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.066, test=-0.132) total time=   4.8s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.067, test=-0.127) total time=   4.9s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.066, test=-0.128) total time=   4.8s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.067, test=-0.127) total time=   4.9s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.066, test=-0.129) total time=   4.8s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.066, test=-0.132) total time=   5.4s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.067, test=-0.127) total time=   5.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.066, test=-0.129) total time=   5.5s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.067, test=-0.127) total time=   5.5s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.066, test=-0.130) total time=   5.6s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.082, test=-0.142) total time=   3.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.083, test=-0.136) total time=   3.0s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.082, test=-0.137) total time=   2.8s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.084, test=-0.136) total time=   3.0s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.083, test=-0.139) total time=   2.9s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.082, test=-0.142) total time=   3.5s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.083, test=-0.138) total time=   3.5s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.082, test=-0.138) total time=   3.4s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.084, test=-0.137) total time=   3.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.082, test=-0.139) total time=   3.5s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.082, test=-0.141) total time=   4.1s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.083, test=-0.136) total time=   4.1s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.082, test=-0.137) total time=   4.1s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.083, test=-0.136) total time=   4.1s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.082, test=-0.139) total time=   4.0s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.082, test=-0.141) total time=   4.8s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.083, test=-0.136) total time=   4.6s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.082, test=-0.137) total time=   4.7s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.083, test=-0.136) total time=   4.6s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.082, test=-0.139) total time=   4.7s
# [CV 1/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.082, test=-0.141) total time=   5.3s
# [CV 2/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.083, test=-0.137) total time=   5.3s
# [CV 3/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.082, test=-0.136) total time=   5.2s
# [CV 4/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.083, test=-0.136) total time=   5.4s
# [CV 5/5] END bootstrap=False, max_features=0.5, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.082, test=-0.139) total time=   5.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.015, test=-0.108) total time=   4.8s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.015, test=-0.101) total time=   7.2s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.015, test=-0.103) total time=   4.9s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.015, test=-0.099) total time=   4.3s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=-0.015, test=-0.104) total time=   5.1s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.015, test=-0.109) total time=   5.5s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.015, test=-0.100) total time=   5.8s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.015, test=-0.103) total time=   5.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.015, test=-0.099) total time=   5.3s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=60;, score=(train=-0.015, test=-0.103) total time=   5.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.015, test=-0.108) total time=   6.4s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.015, test=-0.100) total time=   6.4s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.015, test=-0.104) total time=   8.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.015, test=-0.099) total time=   7.1s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=70;, score=(train=-0.015, test=-0.103) total time=   7.0s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.015, test=-0.107) total time=   8.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.015, test=-0.100) total time=   8.1s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.015, test=-0.103) total time=   7.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.015, test=-0.099) total time=   7.1s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=(train=-0.015, test=-0.104) total time=   7.1s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.014, test=-0.107) total time=   7.9s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.100) total time=   8.2s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.103) total time=   8.0s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.099) total time=   8.9s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=5, n_estimators=90;, score=(train=-0.015, test=-0.103) total time=   9.4s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.043, test=-0.123) total time=   4.7s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.044, test=-0.115) total time=   4.5s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.043, test=-0.117) total time=   4.4s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.044, test=-0.115) total time=   4.8s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=-0.043, test=-0.119) total time=   4.4s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.043, test=-0.122) total time=   5.4s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.043, test=-0.114) total time=   5.3s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.043, test=-0.117) total time=   5.3s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.044, test=-0.114) total time=   5.3s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=60;, score=(train=-0.043, test=-0.118) total time=   5.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.042, test=-0.122) total time=   6.1s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.043, test=-0.114) total time=   6.4s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.043, test=-0.117) total time=   5.9s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.043, test=-0.115) total time=   5.6s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=70;, score=(train=-0.043, test=-0.118) total time=   5.5s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.042, test=-0.122) total time=   6.4s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.043, test=-0.114) total time=   6.4s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.043, test=-0.117) total time=   7.0s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.043, test=-0.115) total time=   7.5s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=80;, score=(train=-0.043, test=-0.118) total time=   7.9s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.042, test=-0.121) total time=   8.0s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.043, test=-0.114) total time=   8.5s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.042, test=-0.117) total time=   8.2s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.043, test=-0.114) total time=   7.1s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=10, n_estimators=90;, score=(train=-0.043, test=-0.117) total time=   7.9s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.065, test=-0.135) total time=   4.3s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.066, test=-0.128) total time=   4.0s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.066, test=-0.129) total time=   4.1s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.067, test=-0.128) total time=   4.0s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=50;, score=(train=-0.065, test=-0.130) total time=   5.0s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.065, test=-0.133) total time=   5.0s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.066, test=-0.127) total time=   5.1s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.065, test=-0.128) total time=   4.9s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.066, test=-0.128) total time=   5.0s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=60;, score=(train=-0.065, test=-0.131) total time=   5.3s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.065, test=-0.133) total time=   6.6s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.066, test=-0.127) total time=   6.3s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.065, test=-0.128) total time=   6.0s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.066, test=-0.127) total time=   6.2s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=70;, score=(train=-0.065, test=-0.130) total time=   5.2s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.065, test=-0.134) total time=   6.0s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.066, test=-0.127) total time=   6.0s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.065, test=-0.129) total time=   5.8s
# [CV 4/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.066, test=-0.127) total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=80;, score=(train=-0.065, test=-0.130) total time=   6.1s
# [CV 1/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.065, test=-0.134) total time=   6.6s
# [CV 2/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.066, test=-0.127) total time=   6.8s
# [CV 3/5] END bootstrap=False, max_features=0.6, min_samples_leaf=1, min_samples_split=15, n_estimators=90;, score=(train=-0.065, test=-0.128) total time=   6.7s
# ...
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.073, test=-0.136) total time=   5.3s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.074, test=-0.133) total time=   5.0s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=50;, score=(train=-0.073, test=-0.135) total time=   4.9s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.073, test=-0.138) total time=   6.3s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.074, test=-0.132) total time=   6.4s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.073, test=-0.135) total time=   6.0s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.074, test=-0.134) total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=60;, score=(train=-0.073, test=-0.136) total time=   5.7s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.073, test=-0.137) total time=   6.9s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.074, test=-0.133) total time=   7.2s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.073, test=-0.135) total time=   6.9s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.074, test=-0.133) total time=   7.6s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=70;, score=(train=-0.073, test=-0.135) total time=   8.2s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.073, test=-0.137) total time=   9.1s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.073, test=-0.133) total time=   8.8s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.072, test=-0.135) total time=   8.2s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.074, test=-0.132) total time=   9.2s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=80;, score=(train=-0.073, test=-0.136) total time=   9.3s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.073, test=-0.138) total time=  10.0s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.073, test=-0.133) total time=  10.5s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.073, test=-0.134) total time=   9.4s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.074, test=-0.133) total time=   9.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=3, min_samples_split=15, n_estimators=90;, score=(train=-0.073, test=-0.135) total time=  10.2s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.056, test=-0.129) total time=   5.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.057, test=-0.124) total time=   5.6s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.056, test=-0.128) total time=   5.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.056, test=-0.123) total time=   5.7s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=-0.056, test=-0.126) total time=   5.5s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.056, test=-0.129) total time=   6.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.057, test=-0.123) total time=   7.2s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.055, test=-0.126) total time=   6.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.056, test=-0.123) total time=   6.6s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=60;, score=(train=-0.056, test=-0.125) total time=   7.1s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.056, test=-0.129) total time=   8.1s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.056, test=-0.124) total time=   8.1s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.056, test=-0.127) total time=   7.7s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.057, test=-0.123) total time=   8.5s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=70;, score=(train=-0.056, test=-0.127) total time=   7.8s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.055, test=-0.129) total time=   9.3s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.056, test=-0.124) total time=   9.8s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.055, test=-0.126) total time=   9.9s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.056, test=-0.123) total time=   8.3s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=80;, score=(train=-0.055, test=-0.126) total time=   9.4s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.056, test=-0.128) total time=  10.1s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.056, test=-0.124) total time=  10.2s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.055, test=-0.126) total time=  10.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.056, test=-0.122) total time=  10.2s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=90;, score=(train=-0.056, test=-0.126) total time=  10.0s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.062, test=-0.132) total time=   5.4s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.062, test=-0.126) total time=   6.0s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.061, test=-0.130) total time=   6.1s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.062, test=-0.125) total time=   5.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=-0.062, test=-0.129) total time=   5.6s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.062, test=-0.132) total time=   7.3s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.062, test=-0.126) total time=   6.6s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.061, test=-0.129) total time=   6.5s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.062, test=-0.125) total time=   6.4s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=60;, score=(train=-0.062, test=-0.129) total time=   6.5s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.061, test=-0.132) total time=   7.4s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.062, test=-0.127) total time=   7.6s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.061, test=-0.129) total time=   7.7s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.062, test=-0.125) total time=   8.1s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=70;, score=(train=-0.062, test=-0.129) total time=   7.7s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.061, test=-0.131) total time=   9.0s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.062, test=-0.126) total time=   8.8s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.061, test=-0.128) total time=   8.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.062, test=-0.125) total time=   8.8s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=80;, score=(train=-0.062, test=-0.129) total time=   8.7s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.061, test=-0.131) total time=  10.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.062, test=-0.126) total time=   9.8s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.061, test=-0.129) total time=   9.7s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.062, test=-0.126) total time=   9.9s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=10, n_estimators=90;, score=(train=-0.061, test=-0.129) total time=  10.1s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.078, test=-0.140) total time=   5.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.078, test=-0.135) total time=   5.5s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.078, test=-0.137) total time=   5.3s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.079, test=-0.135) total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=50;, score=(train=-0.078, test=-0.138) total time=   5.4s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.078, test=-0.140) total time=   6.2s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.079, test=-0.136) total time=   6.1s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.078, test=-0.137) total time=   6.4s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.079, test=-0.134) total time=   7.5s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=60;, score=(train=-0.078, test=-0.138) total time=   6.2s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.078, test=-0.140) total time=   7.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.078, test=-0.135) total time=   7.5s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.078, test=-0.138) total time=   7.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.079, test=-0.136) total time=   8.0s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=70;, score=(train=-0.078, test=-0.138) total time=   7.3s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.078, test=-0.140) total time=   8.3s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.078, test=-0.135) total time=   8.7s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.078, test=-0.138) total time=   8.6s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.079, test=-0.135) total time=   8.7s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=80;, score=(train=-0.078, test=-0.138) total time=   8.4s
# [CV 1/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.077, test=-0.140) total time=   9.6s
# [CV 2/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.078, test=-0.135) total time=  10.3s
# [CV 3/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.077, test=-0.137) total time=   9.8s
# [CV 4/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.078, test=-0.135) total time=   9.9s
# [CV 5/5] END bootstrap=False, max_features=0.8, min_samples_leaf=4, min_samples_split=15, n_estimators=90;, score=(train=-0.077, test=-0.137) total time=   9.7s
# The best parameters are {'bootstrap': False, 'max_features': 0.5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 90} with a score of -0.10
# CPU times: total: 48min 46s
# Wall time: 1h 14min 22s

# %%
result = []


rf_baseline = RandomForestRegressor(random_state = 42)
ml_model = rf_baseline.fit(X_train, y_train)
result.append(model_metrics(ml_model, X_train, y_train, X_test, y_test))
result[0][0] = result[0][0] + "Baseline"


rf_optimezed = RandomForestRegressor(bootstrap = False, max_features = 0.5, min_samples_leaf = 1, min_samples_split = 5, n_estimators = 90, random_state = 42)
ml_model = rf_optimezed.fit(X_train, y_train)
result.append(model_metrics(ml_model, X_train, y_train, X_test, y_test))
result[-1][0] = result[-1][0] + "Optimezed"


result = pd.DataFrame(result, columns = ["Algorithm", "Train_Score", "Test_Score", "Train_RMSE",
                                         "Test_RMSE", "Train_MAE", "Test_MAE", "Train_MAPE", "Test_MAPE"]).sort_values("Test_MAPE").set_index("Algorithm")

result
# Out:
#                                 Train_Score  Test_Score    Train_RMSE  \
# Algorithm
# RandomForestRegressorOptimezed     0.997808    0.921809   6091.775576
# RandomForestRegressorBaseline      0.988368    0.914467  14032.121016
#
#                                    Test_RMSE    Train_MAE     Test_MAE  \
# Algorithm
# RandomForestRegressorOptimezed  36219.746488  2446.054474  16224.40097
# RandomForestRegressorBaseline   37882.163006  6942.234664  19073.24579
#
#                                 Train_MAPE  Test_MAPE
# Algorithm
# RandomForestRegressorOptimezed    0.013698   0.094706
# RandomForestRegressorBaseline     0.040161   0.111830

# %% [markdown]
# ### Аналіз важливості ознак для моделі

# %%
rankings = ml_model.feature_importances_.tolist()
importance = pd.DataFrame(sorted(zip(X_train.columns,rankings),reverse=True),columns=["variable","importance"]).sort_values("importance",ascending = False)

plt.figure(figsize=(8,6))
sns.barplot(x="importance",
            y="variable",
            data=importance[:5])
plt.title('Variable Importance')
plt.tight_layout()
